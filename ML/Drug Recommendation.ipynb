# %%
from sklearn.cluster import KMeans
import numpy as np
import json

# %%
def get_similar_diseases(disease):
    return disease_dataset_to_FDA_disease_mapping.get(disease,[])

# %%
def read_file(path):
    data = None
    with open(path) as json_file: 
        data = json.load(json_file) 
    return data

# %%
disease_dataset_to_FDA_disease_mapping = read_file("zone_1/disease_dataset_FDA_disease.json")
FDA_disease_to_drugs_mapping = read_file("zone_1/disease_drugs.json")
FDA_drugs_to_reactions_mapping = read_file("zone_1/drugs_reactions.json")
disease_dataset_symptom_id_mapping = read_file("zone_1/disease_dataset_symptom_id.json")
FDA_reactions_to_disease_dataset_symptom_mapping = read_file("zone_1/disease_dataset_symptom_FDA_reactions.json")

# %%
def get_drugs_for_disease(disease):
    return FDA_disease_to_drugs_mapping.get(disease,[])

# %%
def get_reactions_for_drug(drug):
    return FDA_drugs_to_reactions_mapping.get(drug,[])

# %%
def get_similar_symptoms(reaction):
    return FDA_reactions_to_disease_dataset_symptom_mapping.get(reaction,[])

# %%
def construct_feature_vector(symptoms):
    num_symptoms = len(disease_dataset_symptom_id_mapping)
    fv = np.zeros((num_symptoms), dtype=int)
    for symptom in symptoms:
        id = disease_dataset_symptom_id_mapping.get(symptom)
        fv[id] = 1
    return fv

# %%
def recommend_drug(disease,symptoms):
    patient_fv = construct_feature_vector(symptoms)
    diseases = get_similar_diseases(disease)
    
    drug_name = []
    drug_fv = []
    for disease in diseases:
        drugs = get_drugs_for_disease(disease)
        for drug in drugs:
            symptoms = []
            reactions = get_reactions_for_drug(drug)
            for reaction in reactions:
                symptoms.extend(get_similar_symptoms(reaction))
            symptoms = list(set(symptoms))
            fv = construct_feature_vector(symptoms)
            drug_name.append(drug)
            drug_fv.append(fv)
    kmeans = KMeans(n_clusters=10, random_state=0).fit(drug_fv)
    #metrics high seperation
    avoid_cluster  = kmeans.predict(patient_fv.reshape(1,-1))
    recommended_drugs= []
    avoided_drugs = []
    for index,drug in enumerate(drug_name):
        if kmeans.labels_[index] == avoid_cluster:
            avoided_drugs.append(drug)
        else:
            recommended_drugs.append(drug)
    
    return recommended_drugs

# %%
recommend_drug('GERD',['polyuria','red_sore_around_nose','back_pain','cold_hands_and_feets','coma'])
# Out:
# ['WARFARINE',
#  'TYMLOS',
#  'EPCLUSA',
#  'Perindopril',
#  'TOPAMAX',
#  'TOLTERODINE',
#  'FOLBEE',
#  'TIAPRIDE',
#  'DOBUTAMINE',
#  'ALENDRONATE SODIUM.',
#  'DEKRISTOL',
#  'ENALAPRIL',
#  'PENICILLIN VK',
#  'BENICAR HCT',
#  'BRILIQUE',
#  'SYSTANE ULTRA',
#  'SINGULAIR',
#  'LUMIFY',
#  'MAGNESIUM CHLORIDE.',
#  'DELSYM',
#  'ESTRACE',
#  'FLEXERIL',
#  'ADALIMUMAB',
#  'Daunorubicin',
#  'PEMETREXED DISODIUM',
#  'BECLOMETHASONE [BECLOMETASONE]',
#  'Prenatal vitamins',
#  'CELEBREX',
#  'Circadin',
#  'MELOXICAM.',
#  'CASSIA SENNA',
#  'MONTELUCAST',
#  'CITRUCEL',
#  'BICALUTAMIDE.',
#  'VITAMIN D2',
#  'CALCIUM W/COLECALCIFEROL',
#  'OMEPRAZOLE MAGNESIUM.',
#  'PANTOPRAZOL',
#  'MIDODRINE HYDROCHLORIDE.',
#  'SENNOSIDE',
#  'DEPO-TESTOSTERONE',
#  'HYDROXYZINE HYDROCHLORIDE.',
#  'DOXAZOSIN MESILATE',
#  'CENTRUM SILVER /07431401/',
#  'CARDENALIN',
#  'AMOXICILLIN/CLAVULANATE POTASSIUM',
#  'CORGARD',
#  'POLARAMINE',
#  'Mepolizumab',
#  'Acetylsalicylic Acid',
#  'HYDROXYZINE',
#  'BROMAZEPAM',
#  'TEPRENONE',
#  'MYSOLINE',
#  'BIOFERMIN /01617201/',
#  'LUMIGAN',
#  'VALSARTAN HCTZ',
#  'AMOXIL',
#  'NOVOLOG',
#  'CANNABIS SATIVA OIL',
#  'PANTOPRAZOLE SODIUM ANHYDROUS',
#  'VERZENIO',
#  'ZOLEDRONIC ACID',
#  'SENNA /00142201/',
#  'FLUZONE QUADRIVALENT NOS',
#  'MYCOPHENOLATE',
#  'FINASTERIDE.',
#  'ZOMIG',
#  'ALDACTAZIDE',
#  'FOSAMAX PLUS D',
#  'CARBATROL',
#  'NESINA',
#  'BENIDIPINE HYDROCHLORIDE',
#  'CELLCEPT',
#  'HYDROXYZINE PAMOATE.',
#  'IRON SULFATE',
#  'TRADJENTA',
#  'Vitamins',
#  'Baby Aspirin',
#  'CALCITONIN',
#  'SALBUTAMOL SULFATE',
#  'ALBENZA',
#  'ONDANSETRON HYDROCHLORIDE.',
#  'KETOROLAC TROMETHAMINE.',
#  'Carfilzomib',
#  'STEMETIL [PROCHLORPERAZINE]',
#  'OMEGA-3 ACIDS',
#  'SOTALOL HCL',
#  'LIDOCAINE HYDROCHLORIDE.',
#  'ELAGOLIX',
#  'Calcium citrate',
#  'PREVIDENT',
#  'LOSEC',
#  'MESALAMINE.',
#  'ZOPHREN CP',
#  'PEGFILGRASTIM',
#  'VANTIN',
#  'NIVOLUMAB',
#  'TRAMADOL/ACETAMINOPHEN',
#  'SENOKOT',
#  'TAVOR (LORAZEPAM)',
#  'FLIVAS',
#  'LUTERA',
#  'ENTOCORT',
#  'APIXABAN',
#  'MICARDIS PLUS',
#  'FLUTICASON',
#  'PILOCARPINE.',
#  'OPANA',
#  'ECULIZUMAB',
#  'VASCEPA',
#  'PAROXETINE HYDROCHLORIDE.',
#  'DOXORUBICIN HYDROCHLORIDE.',
#  'NICOTINE.',
#  'FIBERCON',
#  'BAKTAR',
#  'UNISOM SLEEPGELS NIGHTTIME SLEEP-AID',
#  'LAMOTRIGIN',
#  'PHENERGAN',
#  'GENTAMICIN.',
#  'LEVALBUTEROL /01419301/',
#  'ALLEGRA',
#  'ACEBUTOLOL',
#  'BENFOTIAMINE',
#  'RANITIDINE [RANITIDINE HYDROCHLORIDE]',
#  'SMZ/TMP',
#  'BUDESONIDE;FORMOTEROL',
#  'DIGITOXIN',
#  'SODIUM VALPROATE',
#  'NUCYNTA ER',
#  'VITAMIN A',
#  'NITROFURANTOIN MONOHYDRATE MACROCRYSTALS',
#  'ACETAMINOPHEN AND CODEINE',
#  'CLOPIXOL /00876704/',
#  'ZOCOR',
#  'VAGIFEM',
#  'ISONIAZID.',
#  'NEVANAC',
#  'PRAZOSIN.',
#  'TAZOCIN',
#  'LEVOCETIRIZINE',
#  'FAMVIR',
#  'LOTREL',
#  'AZTREONAM.',
#  'CINACALCET.',
#  'SPIROLACTON',
#  'XANAX',
#  'CEFUROXIME.',
#  'OBINUTUZUMAB.',
#  'VITAMIN A /00056001/',
#  'Proactiv Green Tea Moisturizer',
#  'PREDNISOLON [PREDNISOLONE]',
#  'XL184',
#  'ACLASTA',
#  'LITICAN',
#  'OLMESARTAN',
#  'Vedolizumab',
#  'ROSUVASTATINE',
#  'DESOXIMETASONE.',
#  'VORICONAZOLE.',
#  'HEPARIN LOCK FLUSH',
#  'DIOVAN',
#  'BUPROPION /00700502/',
#  'RESTASIS',
#  'SPIRIVA',
#  'BUMEX',
#  'LABETALOL HYDROCHLORIDE.',
#  'ESTER-C',
#  'POTASSIUM CITRATE.',
#  'CILOXAN',
#  'RANITIDINE HYDROCHLORIDE.',
#  'INDOMETHACIN /00003801/',
#  'BREO ELLIPTA',
#  'HEPARIN SODIUM.',
#  'CALCIUM CITRATE WITH VITAMIN D3',
#  'Oral Treprostinil',
#  'CORTIFOAM',
#  'VALIUM',
#  'IPRATROPIUM BROMIDE.',
#  'HYOSCYAMINE SULFATE.',
#  'OXALIPLATIN.',
#  'BRINZOLAMIDE',
#  'CADUET',
#  'LOVENOX',
#  'BALSALAZIDE',
#  'IBRANCE',
#  'INBRIJA',
#  'CROMOLYN',
#  'REGLAN',
#  'POTASSIUM;SODIUM PHOSPHATE',
#  'Losartan Potassium Film Coated Tablets 100 mg',
#  'LANSOPRAZOLE TEVA',
#  'COLACE',
#  'GRANIX',
#  'Amlor',
#  'SCOPOLAMINE BUTYLBROMIDE',
#  'LAMPRENE',
#  'COLCHICINE.',
#  'BUPROPION XL',
#  'Ferrous fumarate',
#  'PEPCID /00305201/',
#  'ILEVRO',
#  'ORPHENADRINE',
#  'NOVORAPID',
#  'SPASFON [PHLOROGLUCINOL;TRIMETHYLPHLOROGLUCINOL]',
#  'GRANULOCYTE COLONY STIMULATING FACTOR',
#  'AMOXIL [AMOXICILLIN]',
#  'OXYGEN.',
#  'AMOXICILLIN W/CLAVULANIC ACID',
#  'MISOPROSTOL.',
#  'Hydrochlorothiazide;Losartan',
#  'DEXLANSOPRAZOLE',
#  'REQUIP XL',
#  'MULTIPLE VITAMINS WITH MINERALS',
#  'GRAPE SEED EXTRACT',
#  'ALOGLIPTIN.',
#  'FOLIAMIN',
#  'EVISTA',
#  'FLUDROCORTISONE ACETATE.',
#  'PREDNISOLONE.',
#  'FEBUXOSTAT.',
#  'SANDIMMUN',
#  'LINAGLIPTIN',
#  'POSACONAZOLE',
#  'SENNA [SENNOSIDE A+B]',
#  'AURYXIA',
#  'NOREPINEPHRINE.',
#  'POTASSIUM CL ET=R TAB 20 MEQ',
#  'LOTEMAX',
#  'INSTAFLEX JOINT SUPPORT',
#  'ADIPEX-P',
#  'ASPIRIN (CARDIO)',
#  'BENZAMYCIN',
#  'Tolvaptan',
#  'PLAVIX',
#  'L-LYSINE',
#  'LASILIX',
#  'TECTA',
#  'BECONASE AQ',
#  'PROLIA',
#  'NOREPINEPHRINE HYDROCHLORIDE',
#  'INVEGA',
#  'DETROL LA',
#  'SPIRONOLACTONE.',
#  'PALAFER',
#  'HYDROCODONE',
#  'AMIODARONE',
#  'TOPROL XL',
#  '5-FU [FLUOROURACIL]',
#  'RAMUCIRUMAB',
#  'FAMOTIDINE TEVA',
#  'TYLENOL PM',
#  'TRAMADOL.',
#  'AMLODIPINE',
#  'PROMETHAZINE HYDROCHLORIDE.',
#  'PHENOBARBITAL.',
#  'AMOXICILLIN.',
#  'OPIUM TINCTURE',
#  'STATIN /00036501/',
#  'FOLIC ACID.',
#  'NITROFURANTOIN.',
#  'FLUDARABINE',
#  'AZOPT',
#  'IBUPROFEN [IBUPROFEN SODIUM]',
#  'OMEPRAZOLE AND SODIUM BICARBONATE',
#  'CAPTOPRIL.',
#  'VALACYCLOVIR',
#  'NUPLAZID',
#  'SUMATRIPTAN SUCCINATE.',
#  'ACETIC ACID.',
#  'EVENITY',
#  'VITAMIN B12',
#  'BUPROPION HYDROCHLORIDE.',
#  'IMBRUVICA',
#  'GLYBURIDE.',
#  'Infliximab',
#  'Normal Saline',
#  'AMPHO MORONAL',
#  'DOXEPIN HYDROCHLORIDE.',
#  'OXYCODONE-ACETAMINOPHEN',
#  'LEVOFLOXACIN HEMIHYDRATE',
#  'RANITIC',
#  'Kaleorid',
#  'FLURAZEPAM',
#  'ENULOSE',
#  'COLESTIPOL',
#  'GEMFIBROZIL.',
#  'REMODULIN',
#  'OMEPRAZOLE MAGNESIUM DELAYED RELEASE OTC',
#  'PROCARDIA XL',
#  'XGEVA',
#  'VECURONIUM BROMIDE.',
#  'AZELASTINE HYDROCHLORIDE.',
#  'PROACTIV MD ADAPALENE ACNE TREATMENT',
#  'LIXIANA',
#  'SERTRALINE HCL',
#  'PROPANOLOL /00030001/',
#  'BIOTIN 1000 MCG',
#  'CEFZIL',
#  'SODIUM SULFACETAMIDE',
#  'FLUOROURACIL.',
#  'ASA',
#  'BENDAMUSTINE HYDROCHLORIDE.',
#  'ANASTRAZOLE',
#  'AMPYRA',
#  'PREMARIN',
#  'COAPROVEL',
#  'AMOXICILLIN AND CLAVULA. POTASSIUM',
#  'Cyclobenzaprine Tablets',
#  'ESTROGEN',
#  'BRIMONIDINE',
#  'RESTORIL 30 MG',
#  'ASCORBIC ACID.',
#  'AMPHETAMINE',
#  'ZYRTEC-D ALLERGY AND CONGESTION',
#  'MORPHINE SULFATE.',
#  'MACROBID',
#  'DESLORATADINE.',
#  'TRETINOIN.',
#  'MOXIFLOXACIN HYDROCHLORIDE.',
#  'ELIGARD',
#  'ATARAX',
#  'PROAMATINE',
#  'OPIUM.',
#  'Enalapril',
#  'JAKAFI',
#  'CRAVIT',
#  'TAFAMIDIS',
#  'HYDROCORTISONE BUTYRATE.',
#  'LATUDA',
#  'LACTOBACILLUS ACIDOPHILUS',
#  'SEMAGLUTIDE',
#  'NICOTINE TRANSDERMAL SYSTEM',
#  'CONTROLOC',
#  'CALMOSEPTINE',
#  'COTRIM',
#  'Gangiden',
#  'EMLA',
#  'KETALAR',
#  'ESCITALOPRAM OXALATE.',
#  'ARANESP',
#  'MORPHINE SULFATE ER 30 MG',
#  'PIPERACILLIN AND TAZOBACTAM',
#  'VELETRI',
#  'NYSTOP',
#  'ENTACAPONE.',
#  'ZOLPIDEM',
#  'CALCIUM',
#  'UREA.',
#  'SODIUM CITRATE.',
#  'Metformin Hydrochloride Extended-Release Tablets 500 mg',
#  'Hydrocodone',
#  'LEVODOPA',
#  'ALVESCO',
#  'Aspir low',
#  'FLUOCINONIDE.',
#  'FLUTICASONE PROPIONATE.',
#  'CINNAMON.',
#  'CYCLOBENZAPRINE HYDROCHLORIDE.',
#  'CODEINE PHOSPHATE',
#  'TOREM [TORASEMIDE]',
#  'PRIALT',
#  'AMLODIPIN',
#  'TRIAMCINOLONE ACETONIDE.',
#  'BYDUREON',
#  'RELAFEN',
#  'THIAMINE HYDROCHLORIDE.',
#  'PATADAY',
#  'SULFAMETHOXAZOLE/TRIMETHOPRIM',
#  'PROCORALAN',
#  'MESNA.',
#  'OXYCODONE/ACETAMINOPHEN',
#  'SUDAFED',
#  'UNASYN',
#  'COUMADIN',
#  'POTASSIUM CHLORIDE.',
#  'INSULIN HUMAN',
#  'CALCIUM CARBONATE/VITAMIN D3',
#  'AZITHROMYCIN SANDOZ',
#  'HYDROMORPH CONTIN',
#  'LIDOCAINE HCL',
#  'APRISO',
#  'Amiodarone',
#  'Polyethylene glycol',
#  'VITAMIN B COMPLEX',
#  'Melatonin',
#  'FOLINIC ACID',
#  'CALCIUM PLUS VITAMIN D',
#  'NIFUROKSAZYD',
#  'SIMPONI',
#  'VALACICLOVIR /01269702/',
#  'LEVOXYL',
#  'HYDROCODONE BITARTRATE.',
#  'TRELEGY ELLIPTA',
#  'BISOPROLOL',
#  'VIGAMOX',
#  'ACICLOVIR',
#  'GLUCONSAN K',
#  'INJECTAFER',
#  'ATIVAN',
#  'THYRADIN S',
#  'OFLOXACIN.',
#  'POTASSIUM CHLORIDE CRYS ER',
#  'CLINDAMYCIN HYDROCHLORIDE.',
#  'MOVICOL',
#  'Levothyroxin',
#  'DESONIDE.',
#  'Enoxaparin',
#  'CALCIUM VITAMIN D',
#  'OLOPATADINE HCL',
#  'MERCAPTOPURINE.',
#  'REVOLADE',
#  'MIDORINE',
#  'Ipratropium',
#  'SULFAMETHOXAZOLE-TRIMETHOPRIM',
#  'PROPIONATE',
#  'MEDICON',
#  'APAP/CODEINE',
#  'GLUCOSAMINE',
#  'ZEMPLAR',
#  'PROTEIN',
#  'VITAMIN E',
#  'MACRODANTIN',
#  'ADVIL 12HOUR',
#  'TEMODAR',
#  'LONHALA MAGNAIR',
#  'HYDROCORTISONE CREAM',
#  'LINEZOLID.',
#  'GRANISETRON HYDROCHLORIDE.',
#  'ACTHAR',
#  'DITROPAN',
#  'PEG 3350',
#  'TRANXENE',
#  'ROPINIROLE HCL',
#  'AMLODIN',
#  'SERETIDE',
#  'URIEF',
#  'K PHOS NEUTRAL',
#  'POVIDONE-IODINE.',
#  'RECALBON',
#  'COLLAGENASE SANTYL',
#  'MOVANTIK',
#  'PANTOPRAZOLE TEVA',
#  'JANUVIA',
#  'CENTRUM A TO ZINC',
#  'Midodrine HCL',
#  'FOLBIC',
#  'MINOCYCLINE',
#  'COQ10 [UBIDECARENONE]',
#  'TAMIFLU',
#  'Mulitvitamin',
#  'OXYCODONHYDROCHLORID ^ACTAVIS^',
#  'CALCIUM CARBONATE W/COLECALCIFEROL',
#  'METOPROL TAR',
#  'RIGEVIDON',
#  'VITAMIN B6',
#  'APIDRA',
#  'VISIPAQUE',
#  'TREMFYA',
#  'CBD OIL',
#  'GLUCOSAMINE CHONDROITIN [CHONDROITIN SULFATE;GLUCOSAMINE]',
#  'SULFASALAZINE.',
#  'OXYCODONE HYDROCHLORIDE.',
#  'LISINOPRIL/HCTZ',
#  'HYDROQUINONE.',
#  'STILNOCT',
#  'CHOP',
#  'METHOTREXAT',
#  'CETIRIZINE HYDROCHLORIDE.',
#  'CARBIDOPA-LEVODOPA',
#  'LEVOMEPROMAZINE',
#  'PATANOL',
#  'BENDROFLUMETHIAZIDE',
#  'MAG-OX',
#  'LISPRO INSULIN',
#  'MORPHINE SULFATE ER 15 MG',
#  'COMPLERA',
#  'PRILOSEC OTC',
#  'SELBEX',
#  'DYAZIDE',
#  'CIPRODEX',
#  'FEXOFENADINE HCL',
#  'SENNOSIDE [SENNOSIDE A+B]',
#  'ADDERALL',
#  'B6',
#  'Acetaminophen w/hydrocodone',
#  'CANASA',
#  'COCODAMOL',
#  'TRAMADOL HCL',
#  'BUSPAR',
#  'DAUNORUBICIN',
#  'FYCOMPA',
#  'JUNEL FE 1/20',
#  'FORTAMET ER',
#  'DULCOLAX (BISACODYL)',
#  'HUMALOG MIX50/50',
#  'SOLIFENACIN',
#  'BROTIZOLAM',
#  'PRIMPERAN',
#  'CICLOPIROX.',
#  'NAPROSYN',
#  'Valsartan and Hydrochlorothiazide Tablets, USP',
#  'ACTIMINE',
#  'ZADITEN',
#  'ONIVYDE',
#  'ABACAVIR.',
#  'BETNOVAT',
#  'SUMATRIPTAN.',
#  'DOXEPIN HCL',
#  'VENLAFAXIN',
#  'LOSARTAN POTASSIUM.',
#  'PANTOPRAZOLE SODIUM SESQUIHYDRATE',
#  'ESIDREX',
#  'CIPROFLOXACIN HYDROCHLORIDE.',
#  'DIMENHYDRINATE.',
#  'AXIRON',
#  'CIRCADIN',
#  'Ixazomib',
#  'MULTIVITAMIN',
#  'METHYCOBAL',
#  'SIMVASTIN',
#  'IMODIUM',
#  'SIGMART',
#  'SULFAMETHOXAZOL',
#  'CARBAMAZEPIN',
#  'HYDROCHLOROT',
#  'ARNUITY ELLIPTA',
#  'Anoro',
#  'DECITABINE.',
#  'AMARYL',
#  'CLINDAMYCIN HCL',
#  'FLUNARIZINE',
#  'BUPRENORPHINE.',
#  'PRESERVISION AREDS 2',
#  'Pantoprazole',
#  'MAXZIDE',
#  'VITAMIN D [COLECALCIFEROL]',
#  'COLAZAL',
#  'Vancomycin',
#  'SHINGRIX',
#  'PHENOL.',
#  'ACLIDINIUM BROMIDE.',
#  'OMNITROPE',
#  'TORASEMID',
#  'GAVISCON /01409501/',
#  'SIMETHICONE (DIMETHICONE)',
#  'CARTIA [ACETYLSALICYLIC ACID]',
#  'VIANI',
#  'UBIDECARENONE',
#  'HYDROMORPHONE HCL',
#  'DEXAMETHASONE.',
#  'KALEORID',
#  'INTERFERON BETA-1A',
#  'METOPROLOL.',
#  'ACCUPRIL',
#  'RIFAMPIN.',
#  'B COMPLEX /00322001/',
#  'Vit d',
#  'FEROSUL',
#  'THIAMINE.',
#  'MIDOSTAURIN',
#  'DESIPRAMINE',
#  'ENBREL',
#  'Olmesartan',
#  'PREZISTA',
#  'PRINIVIL',
#  'Rabeprazole',
#  'OMEGA 3',
#  'ADALAT',
#  'NIFEDICAL XL',
#  'REXULTI',
#  'LEFLUNOMIDA',
#  'BLACK COHOSH /01456801/',
#  'GLUCOSAMINE + CHONDROITIN /01430901/',
#  'HIPREX',
#  'REFRESH REPAIR',
#  'FLUOCINOLONE',
#  'GRAVOL',
#  'TIZANIDINE HCL',
#  'CEFUROXIME AXETIL.',
#  'Ranitidine Tablets USP, 150 mg',
#  'Acetylsalicylic acid',
#  'ADMELOG',
#  'CHLORHEXIDINE GLUCONATE.',
#  'AZOR',
#  'DEPAKOTE ER',
#  'ELOCON',
#  'NORCO',
#  'DOCUSATE SODIUM.',
#  'HUMULIN N',
#  'GABAPENTINE',
#  'ENTRESTO',
#  'TOVIAZ',
#  'FLUARIX QUAD',
#  'Mometasone',
#  'Ventoline',
#  'LISDEXAMFETAMINE',
#  'REVEFENACIN.',
#  'FLUOXETIN',
#  'FIBER',
#  'MEDROXYPROGESTERONE ACETATE.',
#  'LOPERAMIDE HCL',
#  'ZYTIGA',
#  'ASPIRINE',
#  'SABRIL',
#  'APO-HYDROCHLOROTHIAZIDE',
#  'FLUTICASONE.',
#  'VALTREX',
#  'PROBENECID.',
#  'DIVALPROEX',
#  'VIMOVO',
#  'OMNARIS',
#  'PEGINTERFERON ALFA-2A.',
#  'RUB A535',
#  'DUVOID',
#  'VITAMIN',
#  'LOW DOSE ASPIRIN',
#  'AMOXICILLIN/CLAVULANIC ACID',
#  'PANTOLOC [PANTOPRAZOLE]',
#  'ATROVENT HFA',
#  'MECOBALAMIN',
#  'IRINOTECAN HYDROCHLORIDE.',
#  'IMFINZI',
#  'PREVPAC',
#  'COPRENESSA',
#  'ASPIRIN (E.C.)',
#  'PRADAXA',
#  'Tiorfan',
#  'PANTOLOC /01263204/',
#  'FORMOTEROL FUMARAT',
#  'INSULIN LISPRO',
#  'NITROSTAT',
#  'FLOVENT DISKUS',
#  'COSOPT',
#  'LIORESAL',
#  'CHONDROITIN',
#  'CHLORAMPHENICOL',
#  'DEXAMETHASONE SODIUM PHOSPHATE.',
#  'Dekristol',
#  'Sinvastatina',
#  'DULERA',
#  'EXCEDRIN',
#  'PALBOCICLIB',
#  'NIZORAL',
#  'CANDESARTAN /01349502/',
#  'ERLEADA',
#  'MORPHINE SULPHATE',
#  'BD',
#  'CONCERTA',
#  'Dalteparin sodium',
#  'Eupressyl',
#  'MULTI COMPLETE',
#  'CEFACLOR.',
#  'AMOXICILLINE',
#  'AVODART',
#  'CALCIUM CARBONATE.',
#  'METHOTREXATE SODIUM.',
#  'PROGRAF',
#  'AXITINIB',
#  'IRBESARTAN.',
#  'DEXART',
#  'TRENTAL',
#  'BISACODYL.',
#  'ENSURE',
#  'ROXICODONE',
#  'TRIAMCINOLONE',
#  'HEPARIN FLUSH',
#  'TRUXIMA',
#  'VYVANSE',
#  'APO-DOXEPIN',
#  'HALCION',
#  'BAYER ASPIRIN',
#  'MYLAN PANTOPRAZOLE',
#  'IVIGLOB EX',
#  'CARBOCISTEINE',
#  'FASENRA',
#  'FLEXERIL [CEFIXIME]',
#  'CIMZIA',
#  'VALSARTAN AND HYDROCHLOROTHIAZIDE',
#  'CYANOCOBALAMINE',
#  'XYLOCAINE',
#  'NORMAL SALINE',
#  'EFFEXOR XR',
#  'MIRENA',
#  'DUPIXENT',
#  'CLOZARIL',
#  'MONOCOR',
#  'BENZTROPINE MESYLATE.',
#  'TRESIBA',
#  'BETAMETHASONE DIPROPIONATE.',
#  'RIZATRIPTAN.',
#  'FLURBIPROFEN.',
#  'CISPLATIN.',
#  'TYLENOL 8 HR ARTHRITIS PAIN',
#  'ACIDOPHILUS PROBIOTIC',
#  'FRUSEMIDE',
#  'LOPID',
#  'CARDIZEM [DILTIAZEM HYDROCHLORIDE]',
#  'RISPERDAL',
#  'NOVOLIN NOS',
#  'BUDESONIDE W/FORMOTEROL FUMARATE',
#  'PRENATAL VITAMINS',
#  'ETHAMBUTOL',
#  'TAGRISSO',
#  'CALCIUM LEVOFOLINATE',
#  'PRAVASTATIN SODIUM.',
#  'OXAPROZIN.',
#  'SELENIUM',
#  'OMEGA',
#  'YERVOY',
#  'TURMERIC /01079602/',
#  'CORDARONE',
#  'CALCIUM GLUCONATE.',
#  'ADRENALIN',
#  'PULMICORT TURBUHALER',
#  'DURVALUMAB.',
#  'VYTORIN',
#  'ZALEPLON.',
#  'ROBINUL',
#  'NEPHRO VITE RX',
#  'PROHANCE',
#  'OXYBUTYNIN HYDROCHLORIDE',
#  'BAYER LOW DOSE',
#  'TIZANIDINE HYDROCHLORIDE.',
#  'ALPHA LIPOIC ACID',
#  'NIRAPARIB',
#  'LILETTA',
#  'LORATADIN',
#  'Warfarin',
#  'TORASEMIDE',
#  'CYCLOSPORIN',
#  'METAXALONE.',
#  'REBIF',
#  'SPINRAZA',
#  'METOPROLOL SUCCINATE.',
#  'BROVANA',
#  'COGENTIN',
#  'CO-AMOXICLAV /00756801/',
#  'PLACEBO',
#  'CETRIZINE',
#  'CANAKINUMAB.',
#  'PAXIL',
#  'PROPYLENE GLYCOL',
#  'IMIQUIMOD.',
#  'Piperacillin/Tazobactam',
#  'BELBUCA',
#  'MEMODIN',
#  'VITAMIN D/CALCIUM CITRATE',
#  'LAMIVUDINE.',
#  'CLOBEX',
#  'TEA, GREEN',
#  'SODIUM',
#  'DEPAKOTE',
#  'FLOVENT',
#  'RASAGILINE.',
#  'AFRIN',
#  'MAGNESIUM GLUCONATE',
#  'MYRBETRIQ',
#  'OPTIVAR',
#  'Probiotic',
#  'VRAYLAR',
#  'NITROGLYCERIN.',
#  'SELOZOK',
#  'TRULICITY',
#  'ALFUZOSIN',
#  'GLACTIV',
#  'COVERSYL [PERINDOPRIL ERBUMINE]',
#  'filgrastim',
#  'VALACYCLOVIR HYDROCHLORIDE.',
#  'HARVONI',
#  'HYDRALAZINE HCL',
#  'METHYLDOPA.',
#  'TRIAMTERENE AND HYDROCHLOROTHIAZIDE',
#  'L-THYROXINE',
#  'CODEINE GUAIFENESIN',
#  'SALINE [SODIUM CHLORIDE]',
#  'GLUCONATE',
#  'CALCEOS',
#  'UPTRAVI',
#  'DIPYRIDAMOLE.',
#  'VANDETANIB.',
#  'PIOGLITAZONE HYDROCHLORIDE.',
#  'THERAGRAN [ASCORBIC ACID;BIOTIN;CALCIUM PANTOTHENATE;CYANOCOBALAMIN;ER',
#  'RIFAMPICIN',
#  'DRAMAMINE',
#  'HYDROCORTISONE ACETATE.',
#  'Filgrastim',
#  'PIROXICAM.',
#  'VITAMIN D /07503901/',
#  'ALIGN',
#  'DORZOLAMIDE AND TIMOLOL',
#  'OXYBUTYNIN.',
#  'CLINDAMYCIN.',
#  'FLUCONAZOLE.',
#  'CALCIUM + VITAMIN D',
#  'COTRIMOXAZOL',
#  'AMLODIPINE [AMLODIPINE BESILATE]',
#  'CELECOX',
#  'CANDESARTAN CILEXETIL.',
#  'ESOMEPRAZOL [ESOMEPRAZOLE]',
#  'LACTULOSE.',
#  'EMCONCOR',
#  'GAVISCON /00237601/',
#  'ESCITALOPRAM',
#  'REVLIMID',
#  'TRAZODONE HCL 200 MG',
#  'CALCIPOTRIENE AND BETAMETHASONE DIPROPIONATE',
#  'SEVELAMER CARBONATE.',
#  'ACTISKENAN',
#  'MOXIFLOXACIN.',
#  'BOOSTRIX',
#  'MOBIC',
#  'CITALOPRAM',
#  'PLAQUENIL /00072602/',
#  'GLUCAGEN',
#  'ZOVIRAX',
#  'SECTRAL',
#  'DESVENLAFAXINE SUCCINATE.',
#  'ULTRAM',
#  'LOTRISONE',
#  'CITRACAL',
#  'Midodrine',
#  'CLOPIDOGREL BISULFATE.',
#  'COZAAR',
#  'SAMTIREL',
#  'QUININE SULFATE.',
#  'MORPHINE',
#  'MINIVELLE',
#  'FIORINAL',
#  'VINCRISTINE SULFATE.',
#  'CRIZOTINIB',
#  'METANX',
#  'ASPRIN',
#  'LIALDA',
#  'PROAIR [FLUTICASONE PROPIONATE]',
#  'METOCLOPRAMID',
#  'LACTAID',
#  'CLARITIN',
#  'SPRINTEC',
#  'MIDODRINE',
#  'VENCLEXTA',
#  'TURMERIC',
#  'LOVASTATIN.',
#  'VIVISCAL [SILICON DIOXIDE]',
#  'NOVAMINSULFON',
#  'FLUOXETINE',
#  'SOLIFENACIN SUCCINATE.',
#  'APO-ATORVASTATIN',
#  'CERTOLIZUMAB PEGOL',
#  'FLUTICASONE FUROATE',
#  'QUINAPRIL.',
#  'MEVACOR',
#  'LEVITRA',
#  'GLUCOSAMINE CHONDROITIN',
#  'ENSURE [NUTRIENTS NOS]',
#  'SPECIAFOLDINE',
#  'BUSONID',
#  'PROPYLTHIOURACIL.',
#  'METHOTREXATE.',
#  'BACTRIM',
#  'CALCICHEW D3',
#  'ZINC OXIDE.',
#  'VITAMIN C ACID',
#  'BUPROPION HCL',
#  'DULOXETINE DR',
#  'Asa',
#  'PROMETHEGAN',
#  'AVELOX',
#  'PEPCID [ALUMINIUM HYDROXIDE GEL, DRIED;MAGNESIUM CARBONATE]',
#  'Calcium',
#  'METAMUCIL',
#  'FLIXOTIDE',
#  'PHOSPHONEUROS',
#  'CLARITINE',
#  'CARBIDOPA-LEVODOPA ER',
#  'ALOPURINOL',
#  'DEMADEX',
#  'ZIAC',
#  'ZIAC [BISOPROLOL FUMARATE;HYDROCHLOROTHIAZIDE]',
#  'CRANBERRY 8400 MG',
#  'ESOMEPRAZOLE MAGNESIUM TRIHYDRATE',
#  'ENDEP',
#  'QUESTRAN',
#  'NEXIUM 24HR',
#  'ALBUTEROL HFA',
#  'TIZANIDINE.',
#  'VALSARTAN.',
#  'EDARBI',
#  'ELTROMBOPAG',
#  'DIGOX',
#  'AZOSEMIDE',
#  'KOMBIGLYZE XR',
#  'AMLODIPINE BESILATE/VALSARTAN',
#  'MODAFINIL.',
#  'TRASTUZUMAB.',
#  'BUSPIRONE HCL',
#  'FERINJECT',
#  'Lamivudine.',
#  'CALCIUM WITH VITAMIN D',
#  'CEFEPIME',
#  'PREGABALIN.',
#  'IOHEXOL',
#  'DIFLUCAN',
#  'ELTROXIN',
#  'UMECLIDINIUM',
#  'PSEUDOEPHEDRINE HYDROCHLORIDE.',
#  'TOLTERODINE TARTRATE.',
#  'CANNABIDIOL',
#  'PIPERACILLIN.',
#  'Amitriptyline',
#  'REMERON',
#  'KADIAN',
#  'PAROXETINE HCL',
#  'Potassium',
#  'GLIPIZIDE 5 MG',
#  'ZANTAC',
#  'FLUVIRIN NOS',
#  'Dalteparin',
#  'MAXIDEX',
#  'ALBUTEROL.',
#  'BRUFEN [IBUPROFEN]',
#  'ELIQUIS',
#  'METFORMIN ER',
#  'LACOSAMIDE.',
#  'METHYLPREDNISOLONE ACETATE.',
#  'MULTIVITAMIN + MINERAL',
#  'METFORMIN',
#  'Oxycodone',
#  'TECFIDERA',
#  'MIRALAX',
#  'Glucosamine',
#  'CARISOPRODOL.',
#  'ARCOXIA',
#  'VEROSPIRON',
#  'MEPERIDINE',
#  'BUPROPION.',
#  'CALTRATE [CALCIUM CARBONATE;COLECALCIFEROL]',
#  'VALCYTE',
#  'INDOMETHACIN [INDOMETACIN]',
#  'COMBIVENT',
#  'SEROQUEL XR',
#  'REFRESH CELLUVISC',
#  'MEMANTINE.',
#  'INSULIN GLARGINE',
#  'OLANZAPINE.',
#  'MUCOMYST',
#  'CINRYZE',
#  'AVALIDE',
#  'LENALIDOMIDE',
#  'ENTECAVIR.',
#  'CLARITIN-D NOS',
#  'SINEMET',
#  'CYANOCOBALAMIN.',
#  'ACERTIL',
#  'GAS RELIEF',
#  'INEXIUM',
#  'HALDOL',
#  'MULTIVITAMIN WITH FLUORIDE NOS',
#  'MARINOL',
#  'NITRAZEPAM',
#  'TORADOL',
#  'ESKETAMINE',
#  'REBAMIPIDE',
#  'GAS-X',
#  'CALCIUM + D3 [CALCIUM;COLECALCIFEROL]',
#  'MELPHALAN.',
#  'LONSURF',
#  'DUEXIS',
#  'ATORVASTATIN /01326102/',
#  'APOKYN',
#  'ATOMOXETINE.',
#  'OMNIPAQUE',
#  'CEFAZOLIN',
#  'DIPHENHYDRAMINE.',
#  'GLYCERYL TRINITRATE',
#  'ECOTRIN',
#  'DESYREL',
#  'paracetamol',
#  'ESBRIET',
#  'VOLTAREN [DICLOFENAC]',
#  'PEG',
#  'GLIFAGE',
#  'ITOPRIDE',
#  'CICLOSPORIN',
#  'VIOXX',
#  'ETODOLAC.',
#  'FUROSEMID',
#  'ASPIRIN [ACETYLSALICYLIC ACID]',
#  'PREMPRO',
#  'INTRAVENOUS IMMUNOGLOBULIN',
#  'METOCLOPRAMIDE.',
#  'Zyvoxid',
#  'RISEDRONATE SODIUM - BP',
#  'INLYTA',
#  'LOXAPINE SUCCINATE.',
#  'CODEIN',
#  'LOVAZA',
#  'MOTRIN',
#  'Urapidil',
#  'AXICABTAGENE CILOLEUCEL',
#  ...]
